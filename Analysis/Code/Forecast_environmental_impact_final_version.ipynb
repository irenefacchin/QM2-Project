# %% [markdown]
# <a href="https://colab.research.google.com/github/irenefacchin/QM2-Project/blob/main/Forecast_environmental_impact_final_version.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir data
# Out:
# mkdir: cannot create directory ‘data’: File exists

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab

# !curl https://raw.githubusercontent.com/irenefacchin/QM2-Project/main/Analysis/Code/Environmental%20impact%20fast%20fashion%20vs%20sustainable%20fashion%20(2015)%20v2.csv

wu_path = "https://raw.githubusercontent.com/irenefacchin/QM2-Project/main/Analysis/Code/Environmental%20impact%20fast%20fashion%20vs%20sustainable%20fashion%20(2015)%20v2.csv"
wu = pd.read_csv(wu_path)
wu.head(47)
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `('
# /bin/bash: -c: line 0: `curl https://raw.githubusercontent.com/irenefacchin/QM2-Project/main/Analysis/Code/Environmental%20impact%20fast%20fashion%20vs%20sustainable%20fashion%20(2015)%20v2.csv'
#     Year  ...  Sustainable Fashion CO2 Emissions
# 0   2015  ...                          35046.588
# 1   2016  ...                          37340.722
# 2   2017  ...                          39119.946
# 3   2018  ...                          40865.459
# 4   2019  ...                          42029.011
# 5   2020  ...                          44379.082
# 6   2021  ...                          46135.709
# 7   2022  ...                          47892.706
# 8   2023  ...                          49056.258
# 9   2024  ...                          51372.619
# 10  2025  ...                          53118.503
# 11  2026  ...                          54875.129
# 12  2027  ...                          56620.643
# 13  2028  ...                          58399.866
# 14  2029  ...                          60078.330
#
# [15 rows x 13 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab

wu = pd.read_csv(wu_path)

x = wu['Year']
y1 = wu['Fast Fashion CO2 Emissions']
plt.xlabel('Year') 
plt.ylabel('CO2 Emissions(g)')   
plt.plot(x,y1)
plt.title('CO2 Emissions Forecast Fast Fashion vs Sustainable Fashion')

y2 = wu['Sustainable Fashion CO2 Emissions']
plt.plot(x,y2)

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab

wu = pd.read_csv(wu_path)

x = wu['Year']
y1 = wu['Fast Fashion Water Usage']
plt.xlabel('Year') 
plt.ylabel('Water Usage(L)')   
plt.plot(x,y1)
plt.title('Water Usage Forecast Fast Fashion vs Sustainable Fashion')

y2 = wu['Sustainable Fashion Water Usage']
plt.plot(x,y2)

plt.show()

# %%
#to be more accurate and clear, we also plotted data from 2021 onwards with the same starting point
# !curl https://raw.githubusercontent.com/irenefacchin/QM2-Project/main/Analysis/Code/Environmental%20impact%20fast%20fashion%20vs%20sustainable%20fashion%20(2021)v19.csv
wu2021_path = "https://raw.githubusercontent.com/irenefacchin/QM2-Project/main/Analysis/Code/Environmental%20impact%20fast%20fashion%20vs%20sustainable%20fashion%20(2021)v19.csv"
wu2021 = pd.read_csv(wu2021_path)
wu2021.head(9)
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `('
# /bin/bash: -c: line 0: `curl https://raw.githubusercontent.com/irenefacchin/QM2-Project/main/Analysis/Code/Environmental%20impact%20fast%20fashion%20vs%20sustainable%20fashion%20(2021)v19.csv'
#    Year  Middle class population (billions)  ...  Difference Water Usage   Percentage
# 0  2021                               4.018  ...                      0%           0%
# 1  2022                               4.175  ...                    -60%          10%
# 2  2023                               4.333  ...                    -69%          20%
# 3  2024                               4.435  ...                    -72%          30%
# 4  2025                               4.646  ...                    -74%          40%
# 5  2026                               4.802  ...                    -75%          50%
# 6  2027                               4.958  ...                    -76%          60%
# 7  2028                               5.114  ...                    -77%          70%
# 8  2029                               5.270  ...                    -77%          80%
#
# [9 rows x 17 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab


wu2021 = pd.read_csv(wu2021_path)

x = wu2021['Year']
y1 = wu2021['Total Fast Fashion Water Usage']
plt.xlabel('Year') 
plt.ylabel('Total Water Usage (e+07L)')   
plt.plot(x,y1, color = 'red', label = 'Fast Fashion')
plt.title('Water Usage Forecast Fast Fashion vs Sustainable Fashion')


y2 = wu2021['Total Sustainable Fashion Water Usage']
plt.plot(x,y2, color = 'green', label = 'Sustainable Fashion')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab


wu2021 = pd.read_csv(wu2021_path)

x = wu2021['Year']
y1 = wu2021['Total Fast Fashion CO2 Emissions']
plt.xlabel('Year') 
plt.ylabel('Total CO2 Emissions (e+07g)')   
plt.plot(x,y1, color = 'red', label = 'Fast Fashion')
plt.title('CO2 Emissions Forecast Fast Fashion vs Sustainable Fashion')

y2 = wu2021['Total Sustainable Fashion CO2 Emissions']
plt.plot(x,y2, color = 'green', label = 'Sustainable Fashion')

plt.legend()
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import pylab

# !curl https://raw.githubusercontent.com/irenefacchin/QM2-Project/main/Analysis/Code/Environmental%20impact%20fast%20fashion%20vs%20sustainable%20fashion%20(2021)v19.csv
wu2021_path = "https://raw.githubusercontent.com/irenefacchin/QM2-Project/main/Analysis/Code/Environmental%20impact%20fast%20fashion%20vs%20sustainable%20fashion%20(2021)v19.csv"
wu2021 = pd.read_csv(wu2021_path)
wu2021.head(9)
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `('
# /bin/bash: -c: line 0: `curl https://raw.githubusercontent.com/irenefacchin/QM2-Project/main/Analysis/Code/Environmental%20impact%20fast%20fashion%20vs%20sustainable%20fashion%20(2021)v19.csv'
#    Year  Middle class population (billions)  ...  Difference Water Usage   Percentage
# 0  2021                               4.018  ...                      0%           0%
# 1  2022                               4.175  ...                    -60%          10%
# 2  2023                               4.333  ...                    -69%          20%
# 3  2024                               4.435  ...                    -72%          30%
# 4  2025                               4.646  ...                    -74%          40%
# 5  2026                               4.802  ...                    -75%          50%
# 6  2027                               4.958  ...                    -76%          60%
# 7  2028                               5.114  ...                    -77%          70%
# 8  2029                               5.270  ...                    -77%          80%
#
# [9 rows x 17 columns]

# %%
wu2021 = pd.read_csv(wu2021_path)

#source: https://matplotlib.org/3.1.1/gallery/lines_bars_and_markers/barchart.html

labelx = wu2021['Year']
CO2_Emissions_saved = wu2021['Difference CO2 Emissions']
Water_saved = wu2021['Difference Water Usage']

x = np.arange(len(labelx))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, CO2_Emissions_saved, width, label='Saved CO2 Emissions')
rects2 = ax.bar(x + width/2, Water_saved, width, label='Saved Water')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Saved environmental impact')
ax.set_title('Forecast of saved CO2 emissions and water if the Fashion Industry switches to sustainable')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


fig.tight_layout()

plt.show()
